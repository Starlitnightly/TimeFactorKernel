# %%
import scanpy as sc
import omicverse as ov
import scvelo as scv

ov.ov_plot_set()
# Out:
#    ____            _     _    __
#   / __ \____ ___  (_)___| |  / /__  _____________
#  / / / / __ `__ \/ / ___/ | / / _ \/ ___/ ___/ _ \
# / /_/ / / / / / / / /__ | |/ /  __/ /  (__  )  __/
# \____/_/ /_/ /_/_/\___/ |___/\___/_/  /____/\___/
#
# Version: 1.6.4, Tutorials: https://omicverse.readthedocs.io/
# All dependencies are satisfied.

# %%
ad = sc.read('/data/qin2/Yuqing/cellfate/Lung Myeloid/s2_Macrophages.h5ad')
ad
# Out:
# AnnData object with n_obs × n_vars = 11251 × 33137
#     obs: 'status', 'assignment', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'project', 'domain', 'leiden_R', 'celltype', 'status_summary', 'productive_summary', 'isotype_summary', 'receptor_type', 'receptor_subtype', 'broad_type', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'disease_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id', 'suspension_type', 'tissue_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'pt_via', 'mellon_log_density_lowd'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: 'DM_EigenValues', 'celltype_colors', 'citation', 'default_embedding', 'dendrogram_celltype', 'domain_colors', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'project_colors', 'rank_genes_groups', 'rank_genes_groups_filtered', 'rank_genes_groups_global', 'scaled|original|cum_sum_eigenvalues', 'scaled|original|pca_var_ratios', 'schema_reference', 'schema_version', 'title', 'umap'
#     obsm: 'DM_EigenVectors', 'X_bbknn_umap', 'X_mde_pca', 'X_pca', 'X_umap', 'X_umap_original', 'scaled|original|X_pca'
#     obsp: 'DM_Kernel', 'DM_Similarity', 'connectivities', 'distances'

# %%
ad.X.max()
# Out:
# 8.200345

# %%
ov.pl.embedding(ad,
                basis="X_umap",
                color=['celltype'],title='',size=15,
                show=False, #legend_loc=None, add_outline=False, 
                frameon='small',legend_fontoutline=2,#ax=ax
)
# Out:
# <AxesSubplot: xlabel='X_umap1', ylabel='X_umap2'>

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
fig, ax = plt.subplots(figsize=(6,6))
ov.pl.embedding(
    ad,
    basis="X_umap",
    color=['celltype'],title='',
    show=False,  
    frameon='small',
    size=30,
    palette=ov.pl.red_color[:3]+ov.pl.green_color[:3]+ov.pl.purple_color[:3]+ov.pl.blue_color[:],
    ax=ax,
    legend_loc=None, add_outline=False, 
)

ov.pl.embedding_adjust(
    ad,
    basis="X_umap",
    groupby='celltype',
    ax=ax,
    adjust_kwargs=dict(arrowprops=dict(arrowstyle='-', color='black')),
    text_kwargs=dict(fontsize=12 ,weight='bold',
                     path_effects=[patheffects.withStroke(linewidth=2, foreground='w')] ),
)


plt.title('Human Lung Myeloid Compartment\nscRNA-seq', fontsize=14)
plt.savefig(f'Lung Myeloid/Human Endometrium Epithelial.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/Human Endometrium Epithelial.pdf',dpi=300,bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(3,3))
ov.pl.embedding(
    ad,
    basis="X_umap",
    color=["pt_via"],title='',
    show=False,  
    frameon='small',
    size=10,
    cmap='Reds',
    palette=ov.pl.red_color[:7]+ov.pl.green_color[:6]+ov.pl.blue_color[:],
    ax=ax,
    legend_loc=None, add_outline=False, 
)
ax.set_title('Pseudotime', fontsize=14)
plt.savefig(f'Lung Myeloid/umap-pt-final.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/umap-pt-final.pdf',dpi=300,bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(3,3))
ov.pl.embedding(
    ad,
    basis="X_umap",
    color=['mellon_log_density_lowd'],title='Cell Stage Density',
    show=False,  
    frameon='small',
    size=10,
    cmap='RdBu_r',
    #palette=ov.pl.red_color[:7]+ov.pl.green_color[:6]+ov.pl.blue_color[:],
    ax=ax,
    legend_loc=None, add_outline=False, 
)
ax.set_title('Cell Stage Density', fontsize=14)
plt.savefig(f'Lung Myeloid/umap-mellon-33.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/umap-mellon-33.pdf',dpi=300,bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(3,3))
#x=ad[ad.obs['leiden'].isin(visual_cluster),gene].to_df().values.reshape(-1)
x=ad.obs['pt_via'].values.reshape(-1)
y=ad.obs['mellon_log_density_lowd'].values.reshape(-1)

color_dict=dict(zip(ad.obs['celltype'].cat.categories,
                   ad.uns['celltype_colors']))

from pygam import LinearGAM

gam = LinearGAM(n_splines=25).gridsearch(x.reshape(x.shape[0],1), y)
XX = gam.generate_X_grid(term=0, n=500)

plt.plot(XX, gam.predict(XX), '-',linewidth=3,
        color=ov.pl.red_color[2])
plt.plot(XX, gam.prediction_intervals(XX, width=.65), 
         color=ov.pl.red_color[0], ls='--',linewidth=1,)

ax.scatter(x,y,c=[color_dict[i] for i in ad.obs['celltype'].tolist()],
           cmap='RdBu_r',s=y)

ax.spines['left'].set_position(('outward', 10))
ax.spines['bottom'].set_position(('outward', 10))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)

ax.grid(False)


# 设置标签和标题
ax.set_xlabel('')
ax.set_ylabel('$R^2$', fontsize=13)
ax.set_title('', fontsize=13)
#ax.set_xticks(x + width)
ax.set_xticklabels(ax.get_xticklabels(),  fontsize=11,rotation=0)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=11)

plt.xlabel('Pseudotime',fontsize=12)
plt.ylabel('Cell Stage Density',fontsize=12)
plt.title('',fontsize=12)

plt.savefig(f'Lung Myeloid/density-pt-leiden-33.png',dpi=300,bbox_inches='tight')
#plt.savefig(f'Lung Myeloid/density-pt-33.pdf',dpi=300,bbox_inches='tight')
# Out:
#   0% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--
#   9% (1 of 11) |##                       | Elapsed Time: 0:00:00 ETA:  00:00:00
#  18% (2 of 11) |####                     | Elapsed Time: 0:00:00 ETA:   0:00:00
#  27% (3 of 11) |######                   | Elapsed Time: 0:00:00 ETA:   0:00:00
#  36% (4 of 11) |#########                | Elapsed Time: 0:00:00 ETA:   0:00:00
#  45% (5 of 11) |###########              | Elapsed Time: 0:00:00 ETA:   0:00:00
#  54% (6 of 11) |#############            | Elapsed Time: 0:00:00 ETA:   0:00:00
#  63% (7 of 11) |###############          | Elapsed Time: 0:00:00 ETA:   0:00:00
#  72% (8 of 11) |##################       | Elapsed Time: 0:00:00 ETA:   0:00:00
#  81% (9 of 11) |####################     | Elapsed Time: 0:00:00 ETA:   0:00:00
#  90% (10 of 11) |#####################   | Elapsed Time: 0:00:00 ETA:   0:00:00
# 100% (11 of 11) |########################| Elapsed Time: 0:00:00 Time:  0:00:00

# %%
cfg_obj3=ov.single.Fate(ad,pseudotime='pt_via')
cfg_obj3.model_init(test_size=0.9)
cfg_obj3.ATR(stop=500)
# Out:
# $MSE|RMSE|MAE|R^2$:0.016|0.13|0.1|0.79
# coef_threshold:0.0035323321353644133, r2:0.7751125157882961
#      coef_threshold        r2
# 0          0.009300  0.471167
# 1          0.008085  0.471812
# 2          0.008058  0.492752
# 3          0.007644  0.492906
# 4          0.007152  0.504700
# ..              ...       ...
# 495        0.002511  0.789817
# 496        0.002510  0.790011
# 497        0.002510  0.789985
# 498        0.002510  0.789993
# 499        0.002509  0.790115
#
# [500 rows x 2 columns]

# %%
fig,ax=cfg_obj3.plot_filtering(color='#5ca8dc')
ax.set_title('Macrophages\nOmicFate')
# Out:
# Text(0.5, 1.0, 'Macrophages\nOmicFate')

# %%
res=cfg_obj3.model_fit()
# Out:
# $MSE|RMSE|MAE|R^2$:0.017|0.13|0.1|0.78

# %%
cfg_obj3.plot_fitting(type='raw')
# Out:
# (<Figure size 240x240 with 1 Axes>,
#  <AxesSubplot: title={'center': 'Dimension: 33137'}, xlabel='Raw', ylabel='Predicted'>)

# %%
fig,ax=cfg_obj3.plot_fitting(type='filter',color='#e25d5d')
ax.text(1.1,0.5,'rmse')
# Out:
# Text(1.1, 0.5, 'rmse')

# %%
var_name=cfg_obj3.filter_coef.index.tolist()

# %%
g=ov.utils.plot_heatmap(ad,var_names=var_name,
                  sortby='pt_via',col_color='celltype',
                 n_convolve=1000,figsize=(1,6),show=False,)

g.fig.set_size_inches(2, 8)
g.fig.suptitle('OmicFate',x=0.25,y=0.83,
               horizontalalignment='left',fontsize=12,fontweight='bold')
g.ax_heatmap.set_yticklabels(g.ax_heatmap.get_yticklabels(),fontsize=12)

plt.savefig(f'Lung Myeloid/heatmap_omicfate.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/heatmap_omicfate.pdf',dpi=300,bbox_inches='tight')

# %%
var_name
# Out:
# ['MKI67',
#  'METTL27',
#  'LSP1',
#  'EEF1G',
#  'TPT1',
#  'C1QC',
#  'CLEC11A',
#  'RPS19',
#  'ENSG00000262202',
#  'RPS4Y1',
#  'MALAT1',
#  'LILRB5',
#  'HLA-DQA2',
#  'S100A8',
#  'PARP1',
#  'ENSG00000281181',
#  'FCER1G',
#  'FCN1',
#  'RPS7',
#  'STAB1',
#  'C1QA',
#  'RPL37A',
#  'MS4A6A',
#  'SELENOP',
#  'RPS26',
#  'HLA-C',
#  'H2AZ2',
#  'FOS',
#  'TNFSF9',
#  'IFITM3',
#  'CTSZ',
#  'RPP30',
#  'ANKRD12',
#  'UBE2L3',
#  'GTF3A',
#  'RPS20',
#  'MDH2',
#  'RCSD1',
#  'INSIG1',
#  'RAC2',
#  'H1-2',
#  'GIMAP7',
#  'ERBIN',
#  'TNFAIP8L2',
#  'CCT8',
#  'UQCRC2',
#  'NAIP',
#  'NCF2',
#  'IRF2',
#  'S100A9',
#  'RPL17',
#  'RPSA',
#  'PPT1',
#  'ARL6IP1',
#  'RPS10',
#  'F13A1',
#  'HSPD1',
#  'SURF1',
#  'THOC2',
#  'NPL',
#  'NOP53',
#  'CCDC50',
#  'LIMD2',
#  'NSMCE1',
#  'MIEN1',
#  'FYTTD1',
#  'LY96',
#  'IER5',
#  'GNAI2',
#  'CALM1',
#  'EGR1',
#  'MAFB',
#  'CDC42EP3',
#  'KRAS',
#  'IGSF6',
#  'SEC61G',
#  'HSD17B11',
#  'KLHL24',
#  'SHMT2',
#  'TNFAIP3',
#  'BRI3',
#  'APOE',
#  'CEBPZOS',
#  'RPL9',
#  'SAT2',
#  'WSB1',
#  'SERP1',
#  'ACP2',
#  'CTSD',
#  'LAP3',
#  'DUSP2',
#  'GATD3',
#  'STK17A',
#  'PCBP1',
#  'RNASE1',
#  'LAPTM5',
#  'SREK1',
#  'OS9',
#  'RNASEK',
#  'YIPF6',
#  'STMP1',
#  'SLX1A',
#  'DDX17',
#  'TAOK1',
#  'RNASE6',
#  'ATP5ME',
#  'RBM5',
#  'RPL41',
#  'GAS6',
#  'SERINC1',
#  'EIF1AX',
#  'C1orf43',
#  'SNX6',
#  'DAZAP2',
#  'HNRNPK',
#  'CFP',
#  'POLR1D',
#  'FYB1',
#  'UQCR11',
#  'FGD2',
#  'POLR2K',
#  'GNL3',
#  'SKP1',
#  'SRSF3',
#  'STXBP2']

# %%
ov.pp.leiden(ad,resolution=2)
# Out:
# running Leiden clustering
#     finished: found 32 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:07)

# %%
ov.pl.embedding(ad,
    basis="X_umap",
                  color=['leiden'],title='',#size=15,
                   show=False, #legend_loc=None, add_outline=False, 
                   frameon='small',legend_fontoutline=2,#ax=ax
                 )
# Out:
# <AxesSubplot: xlabel='X_umap1', ylabel='X_umap2'>

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
fig, ax = plt.subplots(figsize=(3,3))
ov.pl.embedding(
    ad,
    basis="X_umap",
    color=['leiden'],title='',
    show=False,  
    frameon='small',
    size=10,
    #palette=ov.pl.red_color[:7]+ov.pl.green_color[:6]+ov.pl.blue_color[:],
    ax=ax,
    legend_loc=None, add_outline=False, 
)

ov.pl.embedding_adjust(
    ad,
    basis="X_umap",
    groupby='leiden',
    ax=ax,
    adjust_kwargs=dict(arrowprops=dict(arrowstyle='-', color='black')),
    text_kwargs=dict(fontsize=12 ,weight='bold',
                     path_effects=[patheffects.withStroke(linewidth=2, foreground='w')] ),
)

ov.pl.contour(ax=ax,adata=ad,
        basis="X_umap",
        groupby='leiden',clusters=['11','20'],
        contour_threshold=0.02,colors='#000000',linestyles='dashed')

ov.pl.contour(ax=ax,adata=ad,
        basis="X_umap",
        groupby='leiden',clusters=[
           '16','20'],
        contour_threshold=0.01,colors='#000000',linestyles='dashed')

plt.title('Clusters', fontsize=14)
plt.savefig(f'Lung Myeloid/umap-leiden.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/umap-leiden.pdf',dpi=300,bbox_inches='tight')

# %%
cfg_obj3.low_density(pca_key='X_pca')
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:03)
# INFO:jax._src.xla_bridge:Unable to initialize backend 'cuda': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INVALID_ARGUMENT: TpuPlatform is not available.
# [2024-07-28 21:41:43,363] [INFO    ] Computing nearest neighbor distances.
# [2024-07-28 21:41:43,526] [WARNING ] Using EXPERIMENTAL fractal dimensionality selection.
# [2024-07-28 21:41:45,223] [INFO    ] Using d=2.169947883186814.
# [2024-07-28 21:41:45,487] [INFO    ] Using covariance function Matern52(ls=0.017306793182921852).
# [2024-07-28 21:41:45,491] [INFO    ] Computing 5,000 landmarks with k-means clustering.
# [2024-07-28 21:41:51,266] [INFO    ] Doing low-rank Cholesky decomposition for 11,251 samples and 5,000 landmarks.
# [2024-07-28 21:41:57,956] [INFO    ] Using rank 5,000 covariance representation.
# [2024-07-28 21:41:59,542] [INFO    ] Running inference using L-BFGS-B.

# %%
ov.pl.embedding(ad,
                basis='X_umap',
                color=['mellon_log_density_lowd','leiden'],
                frameon='small',
               cmap='RdBu_r')

# %%
ad
# Out:
# AnnData object with n_obs × n_vars = 11251 × 33137
#     obs: 'status', 'assignment', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'project', 'domain', 'leiden_R', 'celltype', 'status_summary', 'productive_summary', 'isotype_summary', 'receptor_type', 'receptor_subtype', 'broad_type', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'disease_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id', 'suspension_type', 'tissue_type', 'tissue_ontology_term_id', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'pt_via', 'mellon_log_density_lowd'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: 'celltype_colors', 'citation', 'default_embedding', 'dendrogram_celltype', 'domain_colors', 'leiden', 'neighbors', 'pca', 'project_colors', 'rank_genes_groups', 'rank_genes_groups_filtered', 'rank_genes_groups_global', 'schema_reference', 'schema_version', 'title', 'umap', 'scaled|original|pca_var_ratios', 'scaled|original|cum_sum_eigenvalues', 'leiden_colors', 'DM_EigenValues'
#     obsm: 'X_bbknn_umap', 'X_pca', 'X_umap', 'X_umap_original', 'scaled|original|X_pca', 'X_mde_pca', 'DM_EigenVectors'
#     obsp: 'distances', 'connectivities', 'DM_Kernel', 'DM_Similarity'

# %% [markdown]
# ## Pro-monocyte

# %%
ad.layers['counts'] = ad.X.copy()

# %%
cfg_obj3.lineage_score(cluster_key='leiden',lineage=['20','11','16'],
                      expression_key='counts')
# Out:
# Run low_density first
# 100%|██████████| 11251/11251 [00:27<00:00, 404.32it/s]
# Calculating lineage score
# The lineage score stored in adata.var['change_scores_lineage']

# %%
scores = ad.var["change_scores_lineage"]
scores.sort_values(ascending=False)
# Out:
# CCL4               1.499654e-08
# CCL3               1.223891e-08
# G0S2               1.069397e-08
# HSPA6              1.035359e-08
# HSPB1              1.000662e-08
#                        ...
# ENSG00000274238    0.000000e+00
# INO80B-WBP1        0.000000e+00
# INO80-AS1          0.000000e+00
# ENSG00000276542    0.000000e+00
# hsa-mir-1253       0.000000e+00
# Name: change_scores_lineage, Length: 33137, dtype: float64

# %%
od_genes=scores.loc[cfg_obj3.filter_coef.index].sort_values(ascending=False)[:20]
od_genes
# Out:
# DUSP2      8.502902e-09
# FOS        7.939473e-09
# S100A8     7.865335e-09
# HSPD1      6.325590e-09
# RPS4Y1     5.830790e-09
# TNFAIP3    5.780972e-09
# MAFB       5.628033e-09
# RPL17      5.431663e-09
# MS4A6A     5.357449e-09
# EEF1G      5.159001e-09
# RPS10      5.123788e-09
# RPS26      5.073555e-09
# S100A9     4.856968e-09
# H1-2       4.525309e-09
# RPL41      4.453169e-09
# EGR1       4.426198e-09
# IER5       4.364592e-09
# WSB1       4.295579e-09
# STXBP2     4.295578e-09
# RNASEK     4.279989e-09
# Name: change_scores_lineage, dtype: float64

# %%
del ad.raw

# %%
if 'CCR5' in var_name:
    print("exists")
else:
    print("not exist")
# Out:
# not exist

# %%
ad.var_names
# Out:
# Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A3GALT2', 'A4GALT', 'A4GNT',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=28519)

# %%
ad.obs.columns
# Out:
# Index(['n_genes', 'sample', 'location', 'enrichment', 'cryopreserved', 'TP',
#        'dig_protocol', 'percent_mito', 'n_counts', 'low_ncounts', 'high_mito',
#        'low_ncounts_high_mito', 'S_score', 'G2M_score', 'phase',
#        'scrublet_score', 'scrublet_cluster_score', 'zscore', 'bh_pval',
#        'bonf_pval', 'is_doublet', 'PCW', 'sample_source', 'trimester',
#        'celltype', 'lineage', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'donor_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_ontology_term_id',
#        'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex',
#        'tissue', 'self_reported_ethnicity', 'development_stage',
#        'observation_joinid', 'pt_via', 'leiden', 'mellon_log_density_lowd'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
fig, ax = plt.subplots(figsize=(3,3))

visual_cluster=['20','11','16']
ad.obs['visual']=ad.obs['leiden'].copy()
ad.obs.loc[~ad.obs['leiden'].isin(visual_cluster),'visual']=None
ov.utils.embedding(ad,
                basis='X_umap',frameon='small',
                color=['visual'],
                legend_loc=None,
                #palette=ov.utils.blue_color+ov.utils.orange_color+ov.utils.red_color+ov.utils.green_color,
                show=False,
                  ax=ax)

ov.pl.embedding_adjust(
    ad,
    basis="X_umap",
    groupby='celltype',
    exclude=tuple(set(ad.obs['celltype'].cat.categories)-set(['CD16+ mono', 'Pro-monocyte', 'S100A12-hi CD14+ mono'])),  
    ax=ax,
    adjust_kwargs=dict(arrowprops=dict(arrowstyle='-', color='black')),
    text_kwargs=dict(fontsize=12 ,weight='bold',
                     path_effects=[patheffects.withStroke(linewidth=2, foreground='w')] ),
)

ov.pl.contour(ax=ax,adata=ad,
        basis="X_umap",
        groupby='leiden',clusters=visual_cluster,
        contour_threshold=0.02,colors=ov.pl.red_color[2],linestyles='dashed')

plt.title('Pro-Monocyte\nscRNA-seq', fontsize=14)
plt.savefig(f'Lung Myeloid/umap-lineage-pres.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/umap-lineage-pres.pdf',dpi=300,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
g=ov.utils.plot_heatmap(ad[ad.obs['leiden'].isin(visual_cluster)],
                        var_names=scores.loc[cfg_obj3.filter_coef.index].sort_values(ascending=False)[:10].index.tolist(),
                  sortby='pt_via',col_color='leiden',yticklabels=True,
                 n_convolve=100,figsize=(1,6),show=False)

g.fig.set_size_inches(1, 4)
g.ax_heatmap.set_yticklabels(g.ax_heatmap.get_yticklabels(),fontsize=10)

plt.savefig(f'Lung Myeloid/heatmap-lineage-pres-leiden-24.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/heatmap-lineage-pres-leiden-24.pdf',dpi=300,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
g=ov.utils.plot_heatmap(ad[ad.obs['celltype'].isin(['CD16+ mono', 'Pro-monocyte', 'S100A12-hi CD14+ mono'])],
                        var_names=scores.loc[cfg_obj3.filter_coef.index].sort_values(ascending=False)[:10].index.tolist(),
                  sortby='pt_via',col_color='celltype',yticklabels=True,
                 n_convolve=150,figsize=(1,6),show=False)

g.fig.set_size_inches(1, 4)
g.ax_heatmap.set_yticklabels(g.ax_heatmap.get_yticklabels(),fontsize=10)

plt.savefig(f'Lung Myeloid/heatmap-lineage-pres-ct-24.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/heatmap-lineage-pres-ct-24.pdf',dpi=300,bbox_inches='tight')

# %%
# 创建横向柱状图
import matplotlib.cm as cm
fig, ax = plt.subplots(figsize=(0.5, 3))

od_genes=scores.loc[cfg_obj3.filter_coef.index].sort_values(ascending=False)[:10]

norm = plt.Normalize(min(od_genes.values), max(od_genes.values))
colors = cm.Blues(norm(od_genes.values))

plt.barh(od_genes.index, od_genes.values, color=colors)

ax.spines['left'].set_position(('outward', 10))
ax.spines['bottom'].set_position(('outward', 10))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)

ax.grid(False)

# 设置标签和标题
ax.set_xlabel('')
ax.set_ylabel('$R^2$', fontsize=13)
ax.set_title('', fontsize=13)
ax.set_xlim(0,1e-08)
#ax.set_xticks(x + width)
ax.set_xticklabels(ax.get_xticklabels(),  fontsize=11,rotation=0)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=11)

plt.xlabel('Scores',fontsize=12)
plt.ylabel('Genes',fontsize=12)
plt.title('Fate Rank',fontsize=12)
plt.gca().invert_yaxis()  # 反转y轴使得最高分数在顶部

plt.savefig(f'Lung Myeloid/fr-lineage-pres-33.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/fr-lineage-pres-33.pdf',dpi=300,bbox_inches='tight')

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(3,3))

gene='S100A8'
visual_cluster=['20','11','16','18']

x=ad[ad.obs['leiden'].isin(visual_cluster),gene].to_df().values.reshape(-1)
y=ad.obs.loc[ad.obs['leiden'].isin(visual_cluster),'pt_via'].values.reshape(-1)
z=ad.obs.loc[ad.obs['leiden'].isin(visual_cluster),'mellon_log_density_lowd'].values.reshape(-1)

sns.kdeplot(
        x=x, y=y,
        fill=True,
        cmap='Blues',
        #clip=(-5, 5), cut=10,
        thresh=0.1, levels=15,
        ax=ax,#cbar=True,
    )
scatter=ax.scatter(x,y,
           c=z, s=x*10,
           cmap='RdBu_r',
          )

ax.spines['left'].set_position(('outward', 10))
ax.spines['bottom'].set_position(('outward', 10))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)

ax.grid(False)

plt.xlabel('Expression',fontsize=13)
plt.ylabel('Pseudotime',fontsize=13)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.title(gene,fontsize=13)
cbar = plt.colorbar(scatter, ax=ax,shrink=0.5)
cbar.set_label('Density', fontsize=13)
cbar.ax.tick_params(labelsize=12)

plt.savefig(f'Lung Myeloid/density-lineage-pres-{gene}.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/density-lineage-pres-{gene}.pdf',dpi=300,bbox_inches='tight')

#cbar.set_ticklabels(cbar.get_ticklabels(),fontsize=12)

# %%
fig, ax = plt.subplots(figsize=(3,3))

#visual_cluster=['15','12']
#ad.obs['visual']=ad.obs['leiden'].copy()
#ad.obs.loc[~ad.obs['leiden'].isin(visual_cluster),'visual']=None
ov.utils.embedding(ad,
                basis='X_umap',frameon='small',
                color=[gene],
                legend_loc=None,
                #palette=ov.utils.blue_color+ov.utils.orange_color+ov.utils.red_color+ov.utils.green_color,
                show=False,
                ax=ax)
plt.savefig(f'Lung Myeloid/umap-lineage-B-{gene}.png',dpi=300,bbox_inches='tight')
plt.savefig(f'Lung Myeloid/umap-lineage-B-{gene}.pdf',dpi=300,bbox_inches='tight')
